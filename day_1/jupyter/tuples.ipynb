# %%
tuple1 = (5, 10)

print("1: ", tuple1)
print("2: ", type(tuple1))

tuple[3] = 6
# Out:
# 1:  (5, 10)
# 2:  <class 'tuple'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       3 print("1: ", tuple1)
#       4 print("2: ", type(tuple1))
# ----> 6 tuple[3] = 6
#
# TypeError: 'type' object does not support item assignment
