# %%
prices = {
    "Eggs": 2.99,
    "Milk": 1.99,
    "Bread": 2.49,
    "Butter": 3.49,
}

print("1: ", prices)
print("2: ", type(prices))
print("The price of Milk is ₹", prices["Milk"])
# Out:
# 1:  {'Eggs': 2.99, 'Milk': 1.99, 'Bread': 2.49, 'Butter': 3.49}
# 2:  <class 'dict'>
# The price of Milk is ₹ 1.99
